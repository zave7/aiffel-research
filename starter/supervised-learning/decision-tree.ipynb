# %% [markdown]
# ## 의사결정나무

# %%
# 데이터 로드
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

def make_dataset():
    bc = load_breast_cancer()
    df = pd.DataFrame(bc.data, columns=bc.feature_names)
    df['target'] = bc.target
    X_train, X_test, y_train, y_test = train_test_split(
        df.drop('target', axis=1), df['target'], test_size=0.5, random_state=1004)
    return X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = make_dataset()
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((284, 30), (285, 30), (284,), (285,))

# %% [markdown]
# ### 학습

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

model.fit(X_train, y_train)

pred = model.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9157894736842105

# %% [markdown]
# ### 하이퍼파라미터
# - criterion(gini)
# - max_depth(None)
# - min_sample_split(2)
# - min_sample_leaf(1)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(
    random_state=42, 
    criterion="entropy", 
    max_depth=4, 
    min_samples_leaf=2,
    min_samples_split=3
)

model.fit(X_train, y_train)

pred = model.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9228070175438596

# %% [markdown]
# ## 랜덤포레스트
# - n_estimators(100): 트리의 수
# - criterion(gini): 불순도 지표
# - max_depth(None): 최대 한도 깊이
# - min_sample_split(2): 자식 노드를 갖기 위한 최소한의 데이터 수
# - min_sample_leaf(1): 리프 노드가 되기 위한 최소 샘플 수

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    random_state=42,
    n_estimators=100,
    criterion="entropy", 
    max_depth=4, 
    min_samples_leaf=3,
    min_samples_split=3
)

model.fit(X_train, y_train)

pred = model.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9473684210526315

# %% [markdown]
# ## XGBoost
# - booster(gbtree): 부스팅 알고리즘 (dart, gblinear)
# - objective(binary:logistic): 이진분류 (다중분류: multi:softmax)
# - max_depth(6): 최대 한도 깊이
# - learning_rate(0.1): 학습률
# - n_estimators(100): 트리의 수
# - subsample(1): 훈련 샘플 개수의 비율
# - colsample_bytree(1): 특성 개수의 비율
# - n_jobs(1): 사용 코어 수(-1:모든 코어를 다 사용)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    random_state=42,
    booster="dart",
    objective="binary:logistic",
    n_estimators=500,
    learning_rate=0.05,
    subsample=1,
    colsample_bytree=1,
    n_jobs=-1,
    max_depth=5
)

model.fit(X_train, y_train)

pred = model.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.9649122807017544

# %%
# 조기 종료
from xgboost import XGBClassifier

model = XGBClassifier(
    random_state=42,
    booster="dart",
    objective="binary:logistic",
    n_estimators=500,
    learning_rate=0.05,
    subsample=1,
    colsample_bytree=1,
    n_jobs=-1,
    max_depth=5,
    # early_stopping_rounds=50
)
eval_set = [(X_test, y_test)]
model.fit(X_train, y_train, eval_set=eval_set)

pred = model.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# [0]	validation_0-logloss:0.65133
# [1]	validation_0-logloss:0.61622
# [2]	validation_0-logloss:0.58479
# [3]	validation_0-logloss:0.55575
# [4]	validation_0-logloss:0.53043
# [5]	validation_0-logloss:0.50622
# [6]	validation_0-logloss:0.48445
# [7]	validation_0-logloss:0.46342
# [8]	validation_0-logloss:0.44414
# [9]	validation_0-logloss:0.42749
# [10]	validation_0-logloss:0.41021
# [11]	validation_0-logloss:0.39427
# [12]	validation_0-logloss:0.38104
# [13]	validation_0-logloss:0.36810
# [14]	validation_0-logloss:0.35693
# [15]	validation_0-logloss:0.34518
# [16]	validation_0-logloss:0.33359
# [17]	validation_0-logloss:0.32386
# [18]	validation_0-logloss:0.31363
# [19]	validation_0-logloss:0.30526
# [20]	validation_0-logloss:0.29646
# [21]	validation_0-logloss:0.28918
# [22]	validation_0-logloss:0.28134
# [23]	validation_0-logloss:0.27427
# [24]	validation_0-logloss:0.26860
# [25]	validation_0-logloss:0.26207
# [26]	validation_0-logloss:0.25601
# [27]	validation_0-logloss:0.25163
# [28]	validation_0-logloss:0.24645
# [29]	validation_0-logloss:0.24143
# [30]	validation_0-logloss:0.23782
# [31]	validation_0-logloss:0.23378
# [32]	validation_0-logloss:0.22988
# [33]	validation_0-logloss:0.22635
# [34]	validation_0-logloss:0.22236
# [35]	validation_0-logloss:0.21932
# [36]	validation_0-logloss:0.21653
# [37]	validation_0-logloss:0.21368
# [38]	validation_0-logloss:0.21071
# [39]	validation_0-logloss:0.20835
# [40]	validation_0-logloss:0.20595
# [41]	validation_0-logloss:0.20338
# [42]	validation_0-logloss:0.20099
# [43]	validation_0-logloss:0.19924
# [44]	validation_0-logloss:0.19758
# [45]	validation_0-logloss:0.19529
# [46]	validation_0-logloss:0.19361
# [47]	validation_0-logloss:0.19147
# [48]	validation_0-logloss:0.19015
# [49]	validation_0-logloss:0.18909
# [50]	validation_0-logloss:0.18678
# [51]	validation_0-logloss:0.18497
# [52]	validation_0-logloss:0.18411
# [53]	validation_0-logloss:0.18211
# [54]	validation_0-logloss:0.18095
# [55]	validation_0-logloss:0.18017
# [56]	validation_0-logloss:0.17846
# [57]	validation_0-logloss:0.17762
# [58]	validation_0-logloss:0.17704
# [59]	validation_0-logloss:0.17683
# [60]	validation_0-logloss:0.17539
# [61]	validation_0-logloss:0.17474
# [62]	validation_0-logloss:0.17340
# [63]	validation_0-logloss:0.17311
# [64]	validation_0-logloss:0.17320
# [65]	validation_0-logloss:0.17317
# [66]	validation_0-logloss:0.17247
# [67]	validation_0-logloss:0.17099
# [68]	validation_0-logloss:0.17038
# [69]	validation_0-logloss:0.17045
# [70]	validation_0-logloss:0.17036
# [71]	validation_0-logloss:0.17062
# [72]	validation_0-logloss:0.17039
# [73]	validation_0-logloss:0.16993
# [74]	validation_0-logloss:0.17017
# [75]	validation_0-logloss:0.16980
# [76]	validation_0-logloss:0.16853
# [77]	validation_0-logloss:0.16822
# [78]	validation_0-logloss:0.16817
# [79]	validation_0-logloss:0.16813
# [80]	validation_0-logloss:0.16815
# [81]	validation_0-logloss:0.16827
# [82]	validation_0-logloss:0.16835
# [83]	validation_0-logloss:0.16839
# [84]	validation_0-logloss:0.16860
# [85]	validation_0-logloss:0.16884
# [86]	validation_0-logloss:0.16830
# [87]	validation_0-logloss:0.16857
# [88]	validation_0-logloss:0.16841
# [89]	validation_0-logloss:0.16864
# [90]	validation_0-logloss:0.16900
# [91]	validation_0-logloss:0.16798
# [92]	validation_0-logloss:0.16823
# [93]	validation_0-logloss:0.16851
# [94]	validation_0-logloss:0.16900
# [95]	validation_0-logloss:0.16884
# [96]	validation_0-logloss:0.16916
# [97]	validation_0-logloss:0.16960
# [98]	validation_0-logloss:0.17010
# [99]	validation_0-logloss:0.16998
# [100]	validation_0-logloss:0.16988
# [101]	validation_0-logloss:0.16944
# [102]	validation_0-logloss:0.16931
# [103]	validation_0-logloss:0.16973
# [104]	validation_0-logloss:0.17019
# [105]	validation_0-logloss:0.16989
# [106]	validation_0-logloss:0.17024
# [107]	validation_0-logloss:0.17026
# [108]	validation_0-logloss:0.16990
# [109]	validation_0-logloss:0.17038
# [110]	validation_0-logloss:0.17050
# [111]	validation_0-logloss:0.17020
# [112]	validation_0-logloss:0.16956
# [113]	validation_0-logloss:0.16969
# [114]	validation_0-logloss:0.16942
# [115]	validation_0-logloss:0.16989
# [116]	validation_0-logloss:0.16930
# [117]	validation_0-logloss:0.16902
# [118]	validation_0-logloss:0.16956
# [119]	validation_0-logloss:0.17003
# [120]	validation_0-logloss:0.16978
# [121]	validation_0-logloss:0.16992
# [122]	validation_0-logloss:0.16975
# [123]	validation_0-logloss:0.16941
# [124]	validation_0-logloss:0.16994
# [125]	validation_0-logloss:0.16951
# [126]	validation_0-logloss:0.16898
# [127]	validation_0-logloss:0.16890
# [128]	validation_0-logloss:0.16942
# [129]	validation_0-logloss:0.16988
# [130]	validation_0-logloss:0.16971
# [131]	validation_0-logloss:0.16955
# [132]	validation_0-logloss:0.16940
# [133]	validation_0-logloss:0.16888
# [134]	validation_0-logloss:0.16898
# [135]	validation_0-logloss:0.16882
# [136]	validation_0-logloss:0.16934
# [137]	validation_0-logloss:0.16923
# [138]	validation_0-logloss:0.16885
# [139]	validation_0-logloss:0.16934
# [140]	validation_0-logloss:0.16968
# [141]	validation_0-logloss:0.16963
# [142]	validation_0-logloss:0.16914
# [143]	validation_0-logloss:0.16929
# [144]	validation_0-logloss:0.16945
# [145]	validation_0-logloss:0.16932
# [146]	validation_0-logloss:0.16974
# [147]	validation_0-logloss:0.16922
# [148]	validation_0-logloss:0.16969
# [149]	validation_0-logloss:0.16930
# [150]	validation_0-logloss:0.16925
# [151]	validation_0-logloss:0.16912
# [152]	validation_0-logloss:0.16902
# [153]	validation_0-logloss:0.16948
# [154]	validation_0-logloss:0.16936
# [155]	validation_0-logloss:0.16929
# [156]	validation_0-logloss:0.16925
# [157]	validation_0-logloss:0.16955
# [158]	validation_0-logloss:0.16944
# [159]	validation_0-logloss:0.16940
# [160]	validation_0-logloss:0.16903
# [161]	validation_0-logloss:0.16947
# [162]	validation_0-logloss:0.16944
# [163]	validation_0-logloss:0.16907
# [164]	validation_0-logloss:0.16940
# [165]	validation_0-logloss:0.16929
# [166]	validation_0-logloss:0.16972
# [167]	validation_0-logloss:0.16968
# [168]	validation_0-logloss:0.16933
# [169]	validation_0-logloss:0.16923
# [170]	validation_0-logloss:0.16955
# [171]	validation_0-logloss:0.16953
# [172]	validation_0-logloss:0.16919
# [173]	validation_0-logloss:0.16917
# [174]	validation_0-logloss:0.16959
# [175]	validation_0-logloss:0.16949
# [176]	validation_0-logloss:0.16917
# [177]	validation_0-logloss:0.16948
# [178]	validation_0-logloss:0.16946
# [179]	validation_0-logloss:0.16913
# [180]	validation_0-logloss:0.16903
# [181]	validation_0-logloss:0.16945
# [182]	validation_0-logloss:0.16943
# [183]	validation_0-logloss:0.16974
# [184]	validation_0-logloss:0.16965
# [185]	validation_0-logloss:0.16934
# [186]	validation_0-logloss:0.16932
# [187]	validation_0-logloss:0.16963
# [188]	validation_0-logloss:0.16954
# [189]	validation_0-logloss:0.16994
# [190]	validation_0-logloss:0.16964
# [191]	validation_0-logloss:0.16963
# [192]	validation_0-logloss:0.16991
# [193]	validation_0-logloss:0.16960
# [194]	validation_0-logloss:0.16959
# [195]	validation_0-logloss:0.16950
# [196]	validation_0-logloss:0.16980
# [197]	validation_0-logloss:0.16951
# [198]	validation_0-logloss:0.16950
# [199]	validation_0-logloss:0.16942
# [200]	validation_0-logloss:0.16971
# [201]	validation_0-logloss:0.16971
# [202]	validation_0-logloss:0.16942
# [203]	validation_0-logloss:0.16971
# [204]	validation_0-logloss:0.16963
# [205]	validation_0-logloss:0.16956
# [206]	validation_0-logloss:0.16928
# [207]	validation_0-logloss:0.16928
# [208]	validation_0-logloss:0.16956
# [209]	validation_0-logloss:0.16949
# [210]	validation_0-logloss:0.16977
# [211]	validation_0-logloss:0.16963
# [212]	validation_0-logloss:0.16937
# [213]	validation_0-logloss:0.16936
# [214]	validation_0-logloss:0.16964
# [215]	validation_0-logloss:0.16957
# [216]	validation_0-logloss:0.16950
# [217]	validation_0-logloss:0.16924
# [218]	validation_0-logloss:0.16952
# [219]	validation_0-logloss:0.16952
# [220]	validation_0-logloss:0.16945
# [221]	validation_0-logloss:0.16972
# [222]	validation_0-logloss:0.16959
# [223]	validation_0-logloss:0.16934
# [224]	validation_0-logloss:0.16928
# [225]	validation_0-logloss:0.16955
# [226]	validation_0-logloss:0.16948
# [227]	validation_0-logloss:0.16948
# [228]	validation_0-logloss:0.16975
# [229]	validation_0-logloss:0.16969
# [230]	validation_0-logloss:0.16995
# [231]	validation_0-logloss:0.16983
# [232]	validation_0-logloss:0.16976
# [233]	validation_0-logloss:0.17002
# [234]	validation_0-logloss:0.16997
# [235]	validation_0-logloss:0.17022
# [236]	validation_0-logloss:0.17016
# [237]	validation_0-logloss:0.17016
# [238]	validation_0-logloss:0.16993
# [239]	validation_0-logloss:0.17019
# [240]	validation_0-logloss:0.17013
# [241]	validation_0-logloss:0.17007
# [242]	validation_0-logloss:0.16985
# [243]	validation_0-logloss:0.16986
# [244]	validation_0-logloss:0.17011
# [245]	validation_0-logloss:0.17005
# [246]	validation_0-logloss:0.17031
# [247]	validation_0-logloss:0.17019
# [248]	validation_0-logloss:0.16998
# [249]	validation_0-logloss:0.16999
# [250]	validation_0-logloss:0.17024
# [251]	validation_0-logloss:0.17019
# [252]	validation_0-logloss:0.17014
# [253]	validation_0-logloss:0.17039
# [254]	validation_0-logloss:0.17029
# [255]	validation_0-logloss:0.17053
# [256]	validation_0-logloss:0.17048
# [257]	validation_0-logloss:0.17043
# [258]	validation_0-logloss:0.17068
# [259]	validation_0-logloss:0.17063
# [260]	validation_0-logloss:0.17064
# [261]	validation_0-logloss:0.17088
# [262]	validation_0-logloss:0.17078
# [263]	validation_0-logloss:0.17102
# [264]	validation_0-logloss:0.17097
# [265]	validation_0-logloss:0.17093
# [266]	validation_0-logloss:0.17117
# [267]	validation_0-logloss:0.17112
# [268]	validation_0-logloss:0.17135
# [269]	validation_0-logloss:0.17117
# [270]	validation_0-logloss:0.17118
# [271]	validation_0-logloss:0.17142
# [272]	validation_0-logloss:0.17132
# [273]	validation_0-logloss:0.17115
# [274]	validation_0-logloss:0.17137
# [275]	validation_0-logloss:0.17133
# [276]	validation_0-logloss:0.17156
# [277]	validation_0-logloss:0.17152
# [278]	validation_0-logloss:0.17135
# [279]	validation_0-logloss:0.17136
# [280]	validation_0-logloss:0.17159
# [281]	validation_0-logloss:0.17181
# [282]	validation_0-logloss:0.17172
# [283]	validation_0-logloss:0.17155
# [284]	validation_0-logloss:0.17151
# [285]	validation_0-logloss:0.17135
# [286]	validation_0-logloss:0.17157
# [287]	validation_0-logloss:0.17158
# [288]	validation_0-logloss:0.17142
# [289]	validation_0-logloss:0.17163
# [290]	validation_0-logloss:0.17147
# [291]	validation_0-logloss:0.17149
# [292]	validation_0-logloss:0.17133
# [293]	validation_0-logloss:0.17130
# [294]	validation_0-logloss:0.17151
# [295]	validation_0-logloss:0.17135
# [296]	validation_0-logloss:0.17137
# [297]	validation_0-logloss:0.17122
# [298]	validation_0-logloss:0.17121
# [299]	validation_0-logloss:0.17142
# [300]	validation_0-logloss:0.17127
# [301]	validation_0-logloss:0.17124
# [302]	validation_0-logloss:0.17144
# [303]	validation_0-logloss:0.17129
# [304]	validation_0-logloss:0.17129
# [305]	validation_0-logloss:0.17149
# [306]	validation_0-logloss:0.17173
# [307]	validation_0-logloss:0.17173
# [308]	validation_0-logloss:0.17170
# [309]	validation_0-logloss:0.17193
# [310]	validation_0-logloss:0.17193
# [311]	validation_0-logloss:0.17190
# [312]	validation_0-logloss:0.17190
# [313]	validation_0-logloss:0.17177
# [314]	validation_0-logloss:0.17174
# [315]	validation_0-logloss:0.17162
# [316]	validation_0-logloss:0.17159
# [317]	validation_0-logloss:0.17159
# [318]	validation_0-logloss:0.17147
# [319]	validation_0-logloss:0.17147
# [320]	validation_0-logloss:0.17135
# [321]	validation_0-logloss:0.17135
# [322]	validation_0-logloss:0.17123
# [323]	validation_0-logloss:0.17124
# [324]	validation_0-logloss:0.17112
# [325]	validation_0-logloss:0.17109
# [326]	validation_0-logloss:0.17098
# [327]	validation_0-logloss:0.17099
# [328]	validation_0-logloss:0.17096
# [329]	validation_0-logloss:0.17085
# [330]	validation_0-logloss:0.17083
# [331]	validation_0-logloss:0.17073
# [332]	validation_0-logloss:0.17071
# [333]	validation_0-logloss:0.17069
# [334]	validation_0-logloss:0.17067
# [335]	validation_0-logloss:0.17065
# [336]	validation_0-logloss:0.17064
# [337]	validation_0-logloss:0.17064
# [338]	validation_0-logloss:0.17064
# [339]	validation_0-logloss:0.17064
# [340]	validation_0-logloss:0.17063
# [341]	validation_0-logloss:0.17063
# [342]	validation_0-logloss:0.17063
# [343]	validation_0-logloss:0.17063
# [344]	validation_0-logloss:0.17062
# [345]	validation_0-logloss:0.17062
# [346]	validation_0-logloss:0.17062
# [347]	validation_0-logloss:0.17062
# [348]	validation_0-logloss:0.17061
# [349]	validation_0-logloss:0.17061
# [350]	validation_0-logloss:0.17061
# [351]	validation_0-logloss:0.17061
# [352]	validation_0-logloss:0.17061
# [353]	validation_0-logloss:0.17061
# [354]	validation_0-logloss:0.17060
# [355]	validation_0-logloss:0.17060
# [356]	validation_0-logloss:0.17060
# [357]	validation_0-logloss:0.17060
# [358]	validation_0-logloss:0.17060
# [359]	validation_0-logloss:0.17060
# [360]	validation_0-logloss:0.17059
# [361]	validation_0-logloss:0.17059
# [362]	validation_0-logloss:0.17059
# [363]	validation_0-logloss:0.17059
# [364]	validation_0-logloss:0.17059
# [365]	validation_0-logloss:0.17059
# [366]	validation_0-logloss:0.17059
# [367]	validation_0-logloss:0.17059
# [368]	validation_0-logloss:0.17059
# [369]	validation_0-logloss:0.17058
# [370]	validation_0-logloss:0.17058
# [371]	validation_0-logloss:0.17058
# [372]	validation_0-logloss:0.17058
# [373]	validation_0-logloss:0.17058
# [374]	validation_0-logloss:0.17058
# [375]	validation_0-logloss:0.17058
# [376]	validation_0-logloss:0.17057
# [377]	validation_0-logloss:0.17057
# [378]	validation_0-logloss:0.17057
# [379]	validation_0-logloss:0.17057
# [380]	validation_0-logloss:0.17057
# [381]	validation_0-logloss:0.17057
# [382]	validation_0-logloss:0.17057
# [383]	validation_0-logloss:0.17057
# [384]	validation_0-logloss:0.17057
# [385]	validation_0-logloss:0.17057
# [386]	validation_0-logloss:0.17057
# [387]	validation_0-logloss:0.17057
# [388]	validation_0-logloss:0.17057
# [389]	validation_0-logloss:0.17057
# [390]	validation_0-logloss:0.17057
# [391]	validation_0-logloss:0.17056
# [392]	validation_0-logloss:0.17056
# [393]	validation_0-logloss:0.17056
# [394]	validation_0-logloss:0.17056
# [395]	validation_0-logloss:0.17056
# [396]	validation_0-logloss:0.17056
# [397]	validation_0-logloss:0.17056
# [398]	validation_0-logloss:0.17056
# [399]	validation_0-logloss:0.17056
# [400]	validation_0-logloss:0.17056
# [401]	validation_0-logloss:0.17056
# [402]	validation_0-logloss:0.17056
# [403]	validation_0-logloss:0.17056
# [404]	validation_0-logloss:0.17056
# [405]	validation_0-logloss:0.17056
# [406]	validation_0-logloss:0.17056
# [407]	validation_0-logloss:0.17056
# [408]	validation_0-logloss:0.17056
# [409]	validation_0-logloss:0.17056
# [410]	validation_0-logloss:0.17056
# [411]	validation_0-logloss:0.17056
# [412]	validation_0-logloss:0.17056
# [413]	validation_0-logloss:0.17056
# [414]	validation_0-logloss:0.17056
# [415]	validation_0-logloss:0.17056
# [416]	validation_0-logloss:0.17056
# [417]	validation_0-logloss:0.17056
# [418]	validation_0-logloss:0.17056
# [419]	validation_0-logloss:0.17056
# [420]	validation_0-logloss:0.17056
# [421]	validation_0-logloss:0.17056
# [422]	validation_0-logloss:0.17056
# [423]	validation_0-logloss:0.17056
# [424]	validation_0-logloss:0.17056
# [425]	validation_0-logloss:0.17056
# [426]	validation_0-logloss:0.17056
# [427]	validation_0-logloss:0.17056
# [428]	validation_0-logloss:0.17055
# [429]	validation_0-logloss:0.17055
# [430]	validation_0-logloss:0.17055
# [431]	validation_0-logloss:0.17055
# [432]	validation_0-logloss:0.17055
# [433]	validation_0-logloss:0.17055
# [434]	validation_0-logloss:0.17055
# [435]	validation_0-logloss:0.17055
# [436]	validation_0-logloss:0.17055
# [437]	validation_0-logloss:0.17055
# [438]	validation_0-logloss:0.17055
# [439]	validation_0-logloss:0.17055
# [440]	validation_0-logloss:0.17055
# [441]	validation_0-logloss:0.17055
# [442]	validation_0-logloss:0.17055
# [443]	validation_0-logloss:0.17055
# [444]	validation_0-logloss:0.17055
# [445]	validation_0-logloss:0.17055
# [446]	validation_0-logloss:0.17055
# [447]	validation_0-logloss:0.17055
# [448]	validation_0-logloss:0.17055
# [449]	validation_0-logloss:0.17055
# [450]	validation_0-logloss:0.17055
# [451]	validation_0-logloss:0.17055
# [452]	validation_0-logloss:0.17055
# [453]	validation_0-logloss:0.17055
# [454]	validation_0-logloss:0.17055
# [455]	validation_0-logloss:0.17055
# [456]	validation_0-logloss:0.17055
# [457]	validation_0-logloss:0.17055
# [458]	validation_0-logloss:0.17055
# [459]	validation_0-logloss:0.17055
# [460]	validation_0-logloss:0.17055
# [461]	validation_0-logloss:0.17055
# [462]	validation_0-logloss:0.17055
# [463]	validation_0-logloss:0.17055
# [464]	validation_0-logloss:0.17055
# [465]	validation_0-logloss:0.17055
# [466]	validation_0-logloss:0.17055
# [467]	validation_0-logloss:0.17055
# [468]	validation_0-logloss:0.17055
# [469]	validation_0-logloss:0.17055
# [470]	validation_0-logloss:0.17055
# [471]	validation_0-logloss:0.17055
# [472]	validation_0-logloss:0.17055
# [473]	validation_0-logloss:0.17055
# [474]	validation_0-logloss:0.17055
# [475]	validation_0-logloss:0.17055
# [476]	validation_0-logloss:0.17055
# [477]	validation_0-logloss:0.17055
# [478]	validation_0-logloss:0.17055
# [479]	validation_0-logloss:0.17055
# [480]	validation_0-logloss:0.17055
# [481]	validation_0-logloss:0.17055
# [482]	validation_0-logloss:0.17055
# [483]	validation_0-logloss:0.17055
# [484]	validation_0-logloss:0.17055
# [485]	validation_0-logloss:0.17055
# [486]	validation_0-logloss:0.17055
# [487]	validation_0-logloss:0.17055
# [488]	validation_0-logloss:0.17055
# [489]	validation_0-logloss:0.17055
# [490]	validation_0-logloss:0.17055
# [491]	validation_0-logloss:0.17055
# [492]	validation_0-logloss:0.17055
# [493]	validation_0-logloss:0.17055
# [494]	validation_0-logloss:0.17055
# [495]	validation_0-logloss:0.17055
# [496]	validation_0-logloss:0.17055
# [497]	validation_0-logloss:0.17055
# [498]	validation_0-logloss:0.17055
# [499]	validation_0-logloss:0.17055
# 0.9649122807017544
